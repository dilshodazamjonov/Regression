# %%
import pandas as pd

df = pd.read_parquet("development_sample_parquet", engine="pyarrow")

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027450 entries, 0 to 2027449
# Data columns (total 42 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   PINFL                object
#  1   TIN                  object
#  2   NAME                 object
#  3   ACTIVITY_CODE        object
#  4   BEGIN_DATE           datetime64[ns]
#  5   BUSINESS_STRUCTURE   object
#  6   DISTRICTS_ID         object
#  7   DISTRICT_ID          object
#  8   END_DATE             datetime64[us]
#  9   FAOLIYATI            object
#  10  FORM_TYPE            object
#  11  HUDUD                object
#  12  LIQUIDATION_DATE     datetime64[ns]
#  13  LIQ_DATA             datetime64[ns]
#  14  MFY                  object
#  15  NAME_UZ_CYRL         object
#  16  OKED                 object
#  17  RAHBAR               object
#  18  RAHBARI              object
#  19  RAHBAR_PINFL         object
#  20  REGION_ID            object
#  21  REGISTRATION_NUMBER  object
# ...
